# %%
import json

with open('bertthenerd.json', 'r') as f:
  data = json.load(f)

#display(data['match'])
display(data['timeline']['info']['frames'])
# Out:
# [{'events': [{'realTimestamp': 1654443499404,
#     'timestamp': 0,
#     'type': 'PAUSE_END'}],
#   'participantFrames': {'1': {'championStats': {'abilityHaste': 0,
#      'abilityPower': 0,
#      'armor': 32,
#      'armorPen': 0,
#      'armorPenPercent': 0,
#      'attackDamage': 25,
#      'attackSpeed': 100,
#      'bonusArmorPenPercent': 0,
#      'bonusMagicPenPercent': 0,
#      'ccReduction': 0,
#      'cooldownReduction': 0,
#      'health': 580,
#      'healthMax': 580,
#      'healthRegen': 0,
#      'lifesteal': 0,
#      'magicPen': 0,
#      'magicPenPercent': 0,
#      'magicResist': 30,
#      'movementSpeed': 335,
#      'omnivamp': 0,
#      'physicalVamp': 0,
#      'power': 0,
#      'powerMax': 100,
#      'powerRegen': 0,
#      'spellVamp': 0},
#     'currentGold': 500,
#     'damageStats': {'magicDamageDone': 0,
#      'magicDamageDoneToChampions': 0,
#      'magicDamageTaken': 0,
#      'physicalDamageDone': 0,
#      'physicalDamageDoneToChampions': 0,
# ...

# %%
import matplotlib.pyplot as plt

frames = data['timeline']['info']['frames']

minions = []
print(len(frames))
for frame in frames:
    minions.append((frame["timestamp"], frame['participantFrames']['8']['minionsKilled']))

x, y = zip(*minions)

plt.plot(x, y)
# Out:
# 36

# %%
)
